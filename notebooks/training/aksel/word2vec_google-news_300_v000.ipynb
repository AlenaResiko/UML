# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from kret_studies import *
from kret_studies.notebook import *
from kret_studies.complex import *

logger = get_notebook_logger()
# Out:
# Loaded environment variables from /Users/Akseldkw/coding/Columbia/UML-Project/.env.
# INFO:datasets:JAX version 0.7.2 available.
# /Users/Akseldkw/coding/kretsinger/data/nb_log.log

# %%
from uml_project import *

HF_DIR, HF_REGISTRY, DEVICE_TORCH, MODEL_DIR
# Out:
# (PosixPath('/Users/Akseldkw/coding/Columbia/UML-Project/data/huggingface'),
#  PosixPath('/Users/Akseldkw/coding/Columbia/UML-Project/data/huggingface/REGISTRY.json'),
#  device(type='mps'),
#  PosixPath('/Users/Akseldkw/coding/Columbia/UML-Project/models'))

# %%
from gensim.models.keyedvectors import KeyedVectors


word2vec: KeyedVectors = t.cast(
    gensim.models.keyedvectors.KeyedVectors, gensim_api.load("word2vec-google-news-300", False)
)

# %%
print("Vector size:", word2vec.vector_size)
print("Vocabulary size:", len(word2vec))
# Out:
# Vector size: 300
# Vocabulary size: 3000000

# %%
type(word2vec)
# Out:
# gensim.models.keyedvectors.KeyedVectors

# %%
MODEL_DIR
# Out:
# PosixPath('/Users/Akseldkw/coding/Columbia/UML-Project/models')

# %%
model_name = "word2vec_google-news_300_v000"

# %%
W2VEC_DIR = MODEL_DIR / model_name
fullname = W2VEC_DIR / model_name

# %%
W2VEC_DIR.mkdir(parents=True, exist_ok=True)

# %%
fullname
# Out:
# PosixPath('/Users/Akseldkw/coding/Columbia/UML-Project/models/word2vec_google-news_300_v000/word2vec_google-news_300_v000')

# %%
word2vec.save(str(fullname))

# %%
# word2vec.save_word2vec_format(str(fullname) + ".bin.gz", binary=True)
